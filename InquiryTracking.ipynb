# %%
# Import dependencies
import pandas as pd

# %% [markdown]
# # Inquiry Tracking/Conversion
# -------
# ### 2019

# %%
# Dataframe for 2019 Inquiry Tracking
df_tracker19 = pd.read_csv('Bakken_Resources/2019/Inquiry_Tracking.csv')
df_tracker19
# Out:
#                        Date       Contact Name                          Email  \
# 0                11/12/2018        Anat Shinar            anat@youngdance.org
# 1                12/11/2018    Marcus Pobloske            mpobloske@sabis.net
# 2                12/23/2018        Kate Redden          kate.redden@yahoo.com
# 3                12/28/2018       Alison Crowe                    Weddingwire
# 4                12/28/2018  Bre Lashay Miller                    Weddingwire
# 5                12/28/2018    Ted Bartholomew      ted.bartholomew@gmail.com
# 6                12/29/2018       Matthew Hart         matthewmhart@gmail.com
# 7                  1/4/2019  Andrea Robertson       anniedrobertson@gmail.com
# 8                  1/4/2019       Tina Nguyen       bluecastle2014@gmail.com
# 9                  1/6/2019         Kate Dusek                    Weddingwire
# 10                 1/6/2019     Nicole Geldert       nicole.geldert@gmail.com
# ...

# %%
# Get rid of columns
df_tracker19 = df_tracker19[['Date', 'Event Type', 'Room Request', 'Desired Date', 'Time', 'Group Size',
                             'Contact Method', 'Sent Packet', 'Site Visit', 'Booked Y/N', 'Price']]
df_tracker19
# Out:
#                        Date                      Event Type   Room Request  \
# 0                11/12/2018                      Fundraiser     West Winds
# 1                12/11/2018                            Prom     Classrooms
# 2                12/23/2018                         Meeting            Any
# 3                12/28/2018                         Wedding     West Winds
# 4                12/28/2018                        Wedding      West Winds
# 5                12/28/2018                         Wedding     West Winds
# 6                12/29/2018  Wedding Ceremony and Reception     West Winds
# 7                  1/4/2019                      Reception      West Winds
# 8                  1/4/2019                      Reception      West WInds
# 9                  1/6/2019          Wedding Reception Only     West Winds
# 10                 1/6/2019                      Reception      West Winds
# ...

# %%
#Drop excess rows from the csv
df_tracker19 = df_tracker19.dropna(how = 'all') 
df_tracker19
