# %%
# Import dependencies
import pandas as pd

# %%
test = pd.read_csv('Bakken_Resources/june_count.csv')
test
# Out:
#                  PROGRAM                            BY  \
# 0     General Membership                         Month
# 1                    NaN                           NaN
# 2                 PERIOD                    COUNTTOTAL
# 3                 May-20                           406
# 4                 Jun-20                           407
# 5                    NaN                           NaN
# 6  GROUPEDBYCOLUMN_label  GROUPEDBYCOLUMN_PERIOD_label
# 7                No Type                        May-20
# 8                No Type                        Jun-20
#
#                                    GROUPBY              DATERANGE
# 0                          Membership Type  5/31/2020 to 6/1/2020
# 1                                      NaN                    NaN
# 2                          GROUPEDBYCOLUMN                  COUNT
# 3                                  No Type                    406
# 4                                  No Type                    407
# ...
